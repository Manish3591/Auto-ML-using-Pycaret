# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('bank_train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   REF_NO                           8124 non-null   int64
#  1   children                         8124 non-null   object
#  2   age_band                         8124 non-null   object
#  3   status                           8124 non-null   object
#  4   occupation                       8124 non-null   object
#  5   occupation_partner               8124 non-null   object
#  6   home_status                      8124 non-null   object
#  7   family_income                    8124 non-null   object
#  8   self_employed                    8124 non-null   object
#  9   self_employed_partner            8124 non-null   object
#  10  year_last_moved                  8124 non-null   int64
#  11  TVarea                           8124 non-null   object
# ...

# %%
df.Revenue_Grid.value_counts()
# Out:
# 2    7264
# 1     860
# Name: Revenue_Grid, dtype: int64

# %%
from pycaret.classification import *

# %%
clf1 = setup(data = df, 
          target = 'Revenue_Grid')
# Out:
#                                Description             Value
# 0                               session_id              1758
# 1                                   Target      Revenue_Grid
# 2                              Target Type            Binary
# 3                            Label Encoded        1: 0, 2: 1
# 4                            Original Data        (8124, 32)
# 5                           Missing Values             False
# 6                         Numeric Features                17
# 7                     Categorical Features                14
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set      (5686, 6990)
# 12                    Transformed Test Set      (2438, 6990)
# 13                      Shuffle Train-Test              True
# ...

# %%
clf1 = setup(data = df, 
          target = 'Revenue_grid',fix_imbalance=True)

# %%
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9666  0.9899  0.9882  0.9748
# gbc          Gradient Boosting Classifier    0.9536  0.9676  0.9862  0.9627
# dt               Decision Tree Classifier    0.9486  0.8556  0.9742  0.9685
# ada                  Ada Boost Classifier    0.9441  0.9575  0.9831  0.9556
# lr                    Logistic Regression    0.9413  0.9377  0.9825  0.9532
# rf               Random Forest Classifier    0.9131  0.9633  0.9998  0.9114
# knn                K Neighbors Classifier    0.9119  0.7934  0.9939  0.9148
# ridge                    Ridge Classifier    0.9047  0.0000  0.9955  0.9068
# et                 Extra Trees Classifier    0.8978  0.9393  0.9996  0.8976
# qda       Quadratic Discriminant Analysis    0.8954  0.5139  1.0000  0.8950
# svm                   SVM - Linear Kernel    0.8905  0.0000  0.9147  0.9631
# ...

# %%
gbm  = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9649  0.9886  0.9862  0.9747  0.9804  0.8081  0.8094
# 1       0.9684  0.9922  0.9882  0.9767  0.9824  0.8273  0.8286
# 2       0.9631  0.9887  0.9843  0.9747  0.9794  0.8000  0.8009
# 3       0.9719  0.9938  0.9862  0.9824  0.9843  0.8510  0.8511
# 4       0.9596  0.9881  0.9882  0.9672  0.9776  0.7743  0.7788
# 5       0.9631  0.9888  0.9921  0.9673  0.9796  0.7907  0.7974
# 6       0.9754  0.9857  0.9941  0.9786  0.9863  0.8636  0.8662
# 7       0.9648  0.9878  0.9842  0.9765  0.9804  0.8109  0.8115
# 8       0.9648  0.9920  0.9901  0.9710  0.9805  0.8021  0.8060
# 9       0.9701  0.9935  0.9882  0.9785  0.9833  0.8381  0.8390
# Mean    0.9666  0.9899  0.9882  0.9748  0.9814  0.8166  0.8189
# SD      0.0045  0.0026  0.0030  0.0047  0.0025  0.0265  0.0255

# %%
tuned_gbm = tune_model(gbm)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9613  0.9869  0.9823  0.9746  0.9784  0.7920  0.7926
# 1       0.9701  0.9916  0.9902  0.9767  0.9834  0.8356  0.8375
# 2       0.9596  0.9829  0.9862  0.9691  0.9776  0.7742  0.7772
# 3       0.9701  0.9884  0.9862  0.9804  0.9833  0.8405  0.8408
# 4       0.9649  0.9796  0.9842  0.9765  0.9804  0.8137  0.8143
# 5       0.9666  0.9845  0.9980  0.9656  0.9816  0.8045  0.8171
# 6       0.9630  0.9850  0.9842  0.9746  0.9794  0.7999  0.8009
# 7       0.9595  0.9862  0.9822  0.9727  0.9774  0.7809  0.7818
# 8       0.9595  0.9892  0.9862  0.9690  0.9775  0.7741  0.7772
# 9       0.9630  0.9901  0.9842  0.9746  0.9794  0.7999  0.8009
# Mean    0.9638  0.9864  0.9864  0.9734  0.9798  0.8015  0.8040
# SD      0.0039  0.0034  0.0044  0.0042  0.0022  0.0220  0.0220

# %%
tuned_gbm
# Out:
# LGBMClassifier(bagging_fraction=0.7, bagging_freq=5, boosting_type='gbdt',
#                class_weight=None, colsample_bytree=1.0, feature_fraction=0.9,
#                importance_type='split', learning_rate=0.15, max_depth=-1,
#                min_child_samples=71, min_child_weight=0.001, min_split_gain=0.8,
#                n_estimators=40, n_jobs=-1, num_leaves=200, objective=None,
#                random_state=1758, reg_alpha=1e-06, reg_lambda=0.1, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
predictions = predict_model(tuned_gbm)
# Out:
#                              Model  Accuracy     AUC  ...      F1   Kappa     MCC
# 0  Light Gradient Boosting Machine    0.9688  0.9892  ...  0.9827  0.8218  0.8231
#
# [1 rows x 8 columns]

# %%
evaluate_model(tuned_gbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
